# %% [markdown]
# # American Physics Society data <br> Cross Citations Network Map
#
#
#
# ## Important Notices
#
# <div class="alert alert-block alert-danger">
#     Do not connect to the mongoDB as a read/write user and never run the command drop `collection.drop()`
# </div>
#
#
# All instructions, code comments, etc. in this notebook **are only a recommendation**. That is, feel free to do your own analysis with the data.
#
#
# <div class="alert alert-block alert-success">
#     There are two ways to access the data:
#     <ul>
#   <li>Via MongoDB</li>
#   <li>Via REST api</li>
# </ul>
# </div>
#
# ### data analysis
# As a proposal, the following functions would help in the analysis for the data.
#     <div>
#     <ul>
#         <li>`get_json()`</li>
#         <li>`get_degree()`</li>
#         <li>`list_journals()`</li>
#         <li>`count_journals()`</li>
#         <li>`journals_timeline()`</li>
#         <li>`journal_correlation()`</li>
#     </ul>
#     </div>
#
#
# ### network extract
# As a proposal, the following functions would help in the network data extract.
#     <div>
#     <ul>
#         <li>`get_journal_for_doi()`</li>
#         <li>`get_authors_for_doi()`</li>
#         <li>`get_institutions_for_doi()`</li>
#         <li>`get_doi_list_for_author()`</li>
#         <li>`get_doi_list_for_institution()`</li>
#     </ul>
#     </div>
#
# ### network analysis
# As a proposal, the following functions would help in the network analysis.
#     <div>
#     <ul>
#         <li>`add_node()`</li>
#         <li>`add_edge()`</li>
#         <li>`max_degree_nodes()`</li>
#         <li>`total_nodes()`</li>
#         <li>`total_edges()`</li>
#         <li>`write_edges_file()`</li>
#         <li>`write_nodes_file()`</li>
#         <li>`remove_single_leaf_nodes()`</li>
#     </ul>
#     </div>
#
# ### Helper functions
#
# You are permitted to write additional helper functions, or use additional instance variables so long as the previously described functions work as required.

# %% [markdown]
# #### MongoDB Imports
# <span style="color:red">*Please don't modify the below cell*</span>

# %%
import pymongo
from pymongo import MongoClient

# %% [markdown]
# #### Function to connect to database and collection
# <span style="color:red">*Please don't modify the below cell*</span>

# %%
client = MongoClient("mongodb+srv://phigaread:phigareadpassword@phigacluster0.u54vn.mongodb.net/apsdoi?retryWrites=true&w=majority")
db = client.apsdoi
collection = db.json

# %% [markdown]
# #### Function to check if database connection worked
# <span style="color:red">*Please don't modify the below cell*</span>
# <div>
# <span style="color:green">*There should be 678916 files in the database*</span>
# </div>

# %%
count_files_in_db = len(list(collection.find({},{ "_id": '*'})))
print(count_files_in_db == 678916)
# Out:
# True

# %% [markdown]
# #### Function to allow to run R inside a python notebook
# <span style="color:red">*Please don't modify the below cell*</span>
#
# <div class="alert alert-block alert-danger">
#     please install rpy2 (pip install rpy2)
# </div>

# %%
# %load_ext rpy2.ipython
v = 2
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %% [markdown]
# ### Other Imports
# <div class="alert alert-block alert-success">
#     Please include here all the imports that are required!
# </div>

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# # Implementation for the functions: <br> data analysis

# %% [markdown]
# ### 1. `get_json()` function
#
# This should return the json file by passing the file name. The file name is just the DOI code + ".json". Instead of connecting directly to the mongoDB you could use the REST API located at https://phiga-tech.herokuapp.com/api.
#
# <div class="alert alert-block alert-danger">
#     Since the API is hosted at a free herokuapp box, please first open the link before sending a request otherwise the box may not be active (as heroku disconnects the free boxes to save resources).
# </div>
#
# <div class="alert alert-block alert-success">
#     The reason to use the REST API is that the mongoDB only supports max of 500 connections. While the API will add the request to the API queue and is able to scale this number up.
# </div>

# %%
def get_json(name: str):
    '''
    input: json file name
    output: full json obj
    '''
    # START YOUR CODE HERE ---------
    result = collection.find({'_id': name})
    result = json.dumps(list(result))
    result = json.loads(result)[0]
    # END YOUR CODE HERE -----------
    
    return result

# %%
# check:
# print(get_json("PhysRev.103.525.json"))

# %% [markdown]
# ### 2. `get_degree()` function

# %%
def get_degree(name: str):
    '''
    input: json file name
    output: full json obj
    '''
    # START YOUR CODE HERE ---------
    citing = collection.find({'_id': name},{'citing_doi','cited_doi'})
    citing = json.dumps(list(citing))
    result = len(json.loads(citing)[0]['citing_doi']) + len(json.loads(citing)[0]['cited_doi'])

    # END YOUR CODE HERE -----------
    
    return result

# %%
# check:
# print(get_degree("PhysRev.103.525.json"))

# %% [markdown]
# ### 3. `list_journals()` function

# %%
def list_journals():
    '''
    input: nothing
    output: list of journals (ids)
    '''
    # START YOUR CODE HERE ---------
    result = collection.distinct('journal.id')
    result = list(result)
    
    # END YOUR CODE HERE -----------
    
    return result

# %%
# check:
# list_journals()

# %% [markdown]
# ### 4. `count_journals()` function

# %%
def count_journals(input_data):
    '''
    input: list of journals
    output: count for each
    '''
    # START YOUR CODE HERE ---------
    
    mydata = []
    for x in input_data:
        value = len(list(collection.find({'journal.id': x},{'journal.id'})))
        mydata.append([x,value])
    
    df = pd.DataFrame(mydata, columns = ['journal.id', 'count'])
    result = df.sort_values(by=['count'])
    
    # END YOUR CODE HERE -----------
    
    return result

# %%
# check:
# mylist = list_journals();
# barplot_data = count_journals(mylist)

# %% [markdown]
# ### helper function. `journal_grid_color()` function

# %%
def journal_grid_color():   
    
    # START YOUR CODE HERE ---------
    Journalgrid = [
        ['PR', 'PhysRev',"archive published by the American Physical Society. PROLA provides immediate access to the APS journal collection dating back to the first volume of each journal. A subscription to PROLA gives access to all journal content, except for the current year and the preceding three years"],
        ['PRA', 'PhysRevA', "Physical Review A (PRA) publishes important developments in the rapidly evolving areas of atomic, molecular, and optical (AMO) physics, quantum information, and related fundamental concepts."],
        ['PRAB', 'PhysRevAccelBeams', "Physical Review Accelerators and Beams (PRAB) covers the full spectrum of accelerator science, technology, and applications, including subsystems, component technologies, beam dynamics, and the design, operation, and improvement of scientific and industrial accelerators of all types."],     
        ['PRAPPLIED', 'PhysRevApplied', "Physical Review Applied (PRApplied) publishes high-quality papers that bridge the gap between engineering and physics, and between current and future technologies. PRApplied welcomes papers from both the engineering and physics communities, in academia and industry."],    
        ['PRB', 'PhysRevB', "Physical Review B (PRB) is the world’s largest dedicated physics journal, publishing approximately 100 new, high-quality papers each week. The most highly cited journal in condensed matter physics, PRB provides outstanding depth and breadth of coverage, combined with unrivaled context and background for ongoing research by scientists worldwide."],
        ['PRC','PhysRevC' ,'Physical Review C (PRC) is a leading journal in theoretical and experimental nuclear physics, publishing more than two-thirds of the research literature in the field.'],
        ['PRD',  'PhysRevD','Physical Review D (PRD) is a leading journal in elementary particle physics, field theory, gravitation, and cosmology and is one of the top-cited journals in high-energy physics.'],
        ['PRE',    'PhysRevE' ,'Physical Review E (PRE) is a broad and interdisciplinary journal focusing on collective phenomena of many-body systems. As the premier journal in the interrelated areas of statistical, nonlinear, biological, and soft matter physics, PRE covers recent developments in complex fluids, polymers, liquid crystals, and granular materials. The journal also includes sections on solid mechanics, fluid dynamics, plasma physics, computational physics, networks, and complex systems.'],
        ['PRFLUIDS', 'PhysRevFluids','Physical Review Fluids (PRFluids) is dedicated to publishing innovative research that will significantly advance the fundamental understanding of fluid dynamics. PRFluids embraces both traditional fluid dynamics topics and newer areas, such as bio-related fluid dynamics, micro- and nanoscale flows, fluid mechanics of complex fluids and soft materials, and geophysical and environmental flows.'],
        ['PRI', 'PhysRevSeriesI', 'PROLA provides immediate access to the APS journal collection dating back to the first volume of each journal. A subscription to PROLA gives access to all journal content, except for the current year and the preceding three years.'],
        ['PRL', 'PhysRevLett','Physical Review Letters (PRL) is the world’s premier physics letter journal and the American Physical Society’s flagship publication. Since 1958 it has contributed to APS’s mission to advance and diffuse the knowledge of physics by publishing seminal research by Nobel Prize–winning and other distinguished researchers in all fields of physics.'],  
        ['PRMATERIALS', 'PhysRevMaterials','Physical Review Materials (PRMaterials), launched in 2017, is a broad-scope journal publishing high-quality research on materials. The journal serves the multidisciplinary community working on the prediction, synthesis, processing, structure, properties, and modeling of a wide range of materials.'],
        ['PRPER', 'PhysRevPhysEducRes','Physical Review Physics Education Research (PRPER) covers the full array of experimental and theoretical research relating to the teaching and learning of physics and astronomy. PRPER is the only fully open access journal for physics education research.'],
        ['PRRESEARCH','PhysRevResearch','Physical Review Research (PRResearch) is a fully open access, peer-reviewed journal welcoming the full spectrum of research topics of interest to the physics community and offering authors and readers the Physical Review experience and quality they value and trust.'],
        ['PRSTAB',  'PhysRevSTAB',"Physical Review Accelerators and Beams (PRAB) covers the full spectrum of accelerator science, technology, and applications, including subsystems, component technologies, beam dynamics, and the design, operation, and improvement of scientific and industrial accelerators of all types."],
        ['PRSTPER', 'PhysRevSTPER','Physical Review Physics Education Research (PRPER) covers the full array of experimental and theoretical research relating to the teaching and learning of physics and astronomy. PRPER is the only fully open access journal for physics education research.'],
        ['PRX', 'PhysRevX','Physical Review X (PRX) is an online-only, fully open access journal that places a high value on innovation, quality, and long-term impact in the science it publishes. It seeks to publish a select set of papers from all areas of pure, applied, and interdisciplinary physics that have the potential to influence current and future research and to have a long-lasting and profound impact in their relevant fields.'],
        ['PRXQUANTUM', 'PRXQuantum','PRX Quantum is a highly selective, online-only, fully open access journal that publishes research with an emphasis on outstanding and lasting impact. PRX Quantum seeks to publish a select set of papers providing a home for and connection between the numerous research communities that make up quantum information science and technology, spanning from pure science to engineering to computer science and beyond.'],
        ['RMP','RevModPhys','Reviews of Modern Physics (RMP) is the world’s premier physics review journal and the most highly cited Physical Review publication. Written by leading international researchers, RMP’s in-depth essays provide outstanding coverage of a topic and give context and background for current research trends.'],    
        ['PHYSICS','Physics', 'Physics provides daily online-only news and commentary about a selection of papers from the APS journal collection. The website is aimed at the reader who wants to keep up with highlights of physics research with explanations that don’t rely on jargon and technical detail.'],
        ['PRFOCUS', 'PhysRevFocus','PR Focus is a FREE APS electronic journal featuring highlights of selected Physical Review Letters accessible to all physicists. The editor is David Ehrenstein [see April 1998 APS News]. APS News will print samplings from PR Focus over the next few issues to introduce the membership to this new journal. To receive one-paragraph introductions to Focus stories each week by e-mail, send the following message to majordomo@aps.org: subscribe focus [Leave the subject line blank].'],
        ['PPF', 'PhysicsPhysiqueFizika','As a service to the community, APS has made the small journal “Physics Physique физика” freely available online. The journal published fewer than 100 articles during the period 1964-1968 in four volumes. In their Editorial Foreword, founding editors P. W. Anderson and B. T. Matthias explain that the experimental journal aimed to “alleviate the increasing problems of the communication of science.” During its brief run, the journal published papers by many notable physicists.']
    ]

    columns_colors = ['PR', 'PRA', 'PRAB', 'PRAPPLIED', 'PRB', 'PRC', 'PRD', 'PRE',
           'PRFLUIDS', 'PRI', 'PRL', 'PRMATERIALS', 'PRPER', 'PRRESEARCH',
           'PRSTAB', 'PRSTPER', 'PRX', 'PRXQUANTUM', 'RMP']
    colors_check = []
    for x in Journalgrid[0:19]:
        index_val = columns_colors.index(x[0])
        colors = sns.color_palette("hls", 19)
        colors_check.append(colors[index_val])

    for x in Journalgrid[19:]:
        colors_check.append((0,0,0))

    Journalgriddf = pd.DataFrame(Journalgrid, columns=['id', 'Journal', 'About'])
    Journalgriddf['colour'] = colors_check
    result = Journalgriddf
    
    # END YOUR CODE HERE -----------
    
    return result

# %%
# check:
journalGrid = journal_grid_color()
journalGrid
# Out:
#              id                Journal  \
# 0            PR                PhysRev
# 1           PRA               PhysRevA
# 2          PRAB      PhysRevAccelBeams
# 3     PRAPPLIED         PhysRevApplied
# 4           PRB               PhysRevB
# 5           PRC               PhysRevC
# 6           PRD               PhysRevD
# 7           PRE               PhysRevE
# 8      PRFLUIDS          PhysRevFluids
# 9           PRI         PhysRevSeriesI
# 10          PRL            PhysRevLett
# 11  PRMATERIALS       PhysRevMaterials
# 12        PRPER     PhysRevPhysEducRes
# 13   PRRESEARCH        PhysRevResearch
# 14       PRSTAB            PhysRevSTAB
# 15      PRSTPER           PhysRevSTPER
# 16          PRX               PhysRevX
# 17   PRXQUANTUM             PRXQuantum
# 18          RMP             RevModPhys
# 19      PHYSICS                Physics
# 20      PRFOCUS           PhysRevFocus
# 21          PPF  PhysicsPhysiqueFizika
#
#                                                 About  \
# 0   archive published by the American Physical Soc...
# 1   Physical Review A (PRA) publishes important de...
# 2   Physical Review Accelerators and Beams (PRAB) ...
# 3   Physical Review Applied (PRApplied) publishes ...
# 4   Physical Review B (PRB) is the world’s largest...
# 5   Physical Review C (PRC) is a leading journal i...
# 6   Physical Review D (PRD) is a leading journal i...
# 7   Physical Review E (PRE) is a broad and interdi...
# 8   Physical Review Fluids (PRFluids) is dedicated...
# 9   PROLA provides immediate access to the APS jou...
# 10  Physical Review Letters (PRL) is the world’s p...
# 11  Physical Review Materials (PRMaterials), launc...
# 12  Physical Review Physics Education Research (PR...
# 13  Physical Review Research (PRResearch) is a ful...
# 14  Physical Review Accelerators and Beams (PRAB) ...
# 15  Physical Review Physics Education Research (PR...
# 16  Physical Review X (PRX) is an online-only, ful...
# 17  PRX Quantum is a highly selective, online-only...
# 18  Reviews of Modern Physics (RMP) is the world’s...
# 19  Physics provides daily online-only news and co...
# 20  PR Focus is a FREE APS electronic journal feat...
# 21  As a service to the community, APS has made th...
#
#                                               colour
# 0                (0.86, 0.3712, 0.33999999999999997)
# 1    (0.86, 0.5354105263157893, 0.33999999999999997)
# 2    (0.86, 0.6996210526315789, 0.33999999999999997)
# 3    (0.8561684210526316, 0.86, 0.33999999999999997)
# 4    (0.6919578947368422, 0.86, 0.33999999999999997)
# 5    (0.5277473684210525, 0.86, 0.33999999999999997)
# 6   (0.36353684210526294, 0.86, 0.33999999999999997)
# 7    (0.33999999999999997, 0.86, 0.4806736842105263)
# 8    (0.33999999999999997, 0.86, 0.6448842105263157)
# 9    (0.33999999999999997, 0.86, 0.8090947368421053)
# 10   (0.33999999999999997, 0.7466947368421052, 0.86)
# 11   (0.33999999999999997, 0.5824842105263155, 0.86)
# 12  (0.33999999999999997, 0.41827368421052624, 0.86)
# 13   (0.4259368421052626, 0.33999999999999997, 0.86)
# 14   (0.5901473684210526, 0.33999999999999997, 0.86)
# 15   (0.7543578947368419, 0.33999999999999997, 0.86)
# 16   (0.86, 0.33999999999999997, 0.8014315789473682)
# 17   (0.86, 0.33999999999999997, 0.6372210526315789)
# 18  (0.86, 0.33999999999999997, 0.47301052631578955)
# 19                                         (0, 0, 0)
# 20                                         (0, 0, 0)
# 21                                         (0, 0, 0)

# %% [markdown]
# ### helper function. `barplot_journals()` function

# %%
# check 2 - plot:
def barplot_journals(barplot_data):
    column_values = barplot_data['count']/100000
    column_names = barplot_data['journal.id']

    # frame
    fig, ax = plt.subplots(1, 1, tight_layout=True)
    fig.set_size_inches(8, 7)

    # plot
    
    columns_colors = ['PR', 'PRA', 'PRAB', 'PRAPPLIED', 'PRB', 'PRC', 'PRD', 'PRE',
       'PRFLUIDS', 'PRI', 'PRL', 'PRMATERIALS', 'PRPER', 'PRRESEARCH',
       'PRSTAB', 'PRSTPER', 'PRX', 'PRXQUANTUM', 'RMP']
    
    colors_check = []
    for x in column_names:
        index_val = columns_colors.index(x)
        colors = sns.color_palette("hls", 19)
        colors_check.append(colors[index_val])

    ax.barh(column_names,column_values, color=colors_check,height = 0.9)
#     ax.barh(column_names,column_values, color="black",height = 0.9)

    # font
    mpl.rcParams['font.family'] = 'serif'
    mpl.rcParams['mathtext.fontset'] = 'cm'
    plt.rcParams['font.size'] = 20
    plt.rcParams['axes.linewidth'] = 1

    # Add the x and y-axis labels
    ax.set_xlabel(r'count ($10^5$)', labelpad=10, fontsize=25)
#     ax.set_ylabel(r'journals', labelpad=10, fontsize=25)

    ax.tick_params(which='major',bottom=True, top=True, left=True, right=True, direction = 'in', length=10)
    ax.tick_params(which='minor',bottom=True, top=True, left=True, right=True, direction = 'in', length=5)
    
#     ax.tick_params(which='major',bottom=True, top=True, left=True, right=True, length=10)
#     ax.tick_params(which='minor',bottom=True, top=True, left=True, right=True, length=5)

    # Add title
    plt.title('Journal Count', pad=20)
    # Show/save the plot
    plt.savefig('./fig/barplot_journals.eps', format='eps')
    return plt.show()

# %%
# plot data
mylist = list_journals();
count_data = count_journals(mylist)
barplot_journals(count_data)

# %% [markdown]
# ### 5. `journals_timeline()` function

# %%
def journals_timeline(input_data):
    '''
    input: list of journals
    output: count for each
    '''
    # START YOUR CODE HERE ---------
    
    mydata = []
    for x in input_data:
        extract = list(collection.aggregate([{'$match' : {"journal.id": x,}},
                                      {'$group': {'_id': {'$year': {'$toDate': '$date'}},"count": { "$sum": 1 }}},
                                      { '$sort' : { '_id' : 1 } }
                                ]))
        for y in extract:
            mydata.append([y['_id'],x,y['count']])
    
    
    df = pd.DataFrame(mydata, columns = ['year', 'journal' , 'count'])
    check = df.sort_values(by=['year'])
    
    maindata = pd.DataFrame({'year': check['year'].drop_duplicates()})
    # display(maindata1)
    for jj in input_data:
        mydata1 = []
        mydata2 = []  
        for year in maindata['year']:     
            seq = list(check[(check['year'] == year) & (check['journal'] == jj)]['count'])
            if len(seq)>0:
                mydata1.append(seq[0])
            else:
                mydata1.append(0)
        mydata2 = pd.DataFrame({'year': maindata['year'] , str(jj): mydata1})
        maindata[str(jj)] = mydata2[str(jj)]
    result = maindata
    
    # END YOUR CODE HERE -----------
    
    return result

# %%
# mylist = list_journals();
# check = journals_timeline(mylist)
# display(check)
# check.to_csv('./data/journals_timeline.csv', header='true',index=False)

# %% [markdown]
# ### helper function. `stackplot_journals()` function

# %%
def stackplot_journals(check):
    # frame
    fig, ax = plt.subplots(1, 1, tight_layout=True)
    fig.set_size_inches(8, 7)

    colors = sns.color_palette("hls", 19)
    # plot
    ax.stackplot(check['year'].values, check.drop('year',axis=1).T, colors = colors)
    ax.legend(check.columns.values[1:], prop={'size': 11.4},loc='upper left')

    # font
    mpl.rcParams['font.family'] = 'serif'
    mpl.rcParams['mathtext.fontset'] = 'cm'
    plt.rcParams['font.size'] = 20
    plt.rcParams['axes.linewidth'] = 1

    # Add the x and y-axis labels
    ax.set_xlabel(r'year', labelpad=10, fontsize=25)
    # Specify tick label size


    # limits
    # ax.set_ylim(0, 12)
    ax.set_xlim(1893, 2020)

    # Edit the major and minor tick locations
    ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(20))
    ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(3000))
    ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(1000))
    
    ax.tick_params(which='major',bottom=True, top=True, left=True, right=True, direction = 'in', length=10)
    ax.tick_params(which='minor',bottom=True, top=True, left=True, right=True, direction = 'in', length=5)

#     ax.tick_params(which='major',bottom=True, top=True, left=True, right=True)
#     ax.tick_params(which='minor',bottom=True, top=True, left=True, right=True)
    
    # Add title
    plt.title('Timeline', pad=20)

    plt.savefig('./fig/stackplot.eps', format='eps')
    return plt.show()

# %%
mylist = list_journals();
check = journals_timeline(mylist)
stackplot_journals(check)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# %%R -i check -w 3 -h 2 --units in -r 150

# # this is R... %%R needs to be at the top!
# # import check from global environment
# # make default figure size 3 by 2 inches with 150 dpi resolution


# df = check
# library(ggplot2)
# ggplot(df, aes(x=year, y=PR)) + geom_line()

# %% [markdown]
# ### 6. `journal_correlation()` function
#
#
# <div class="alert alert-block alert-danger">
#    This will be done in another notebook as we require to manipulate a 9mio 64bits array in memory. Please open the `citations_df` to cotinue with the jour journal_correlation.
# </div>
# </div>

# %% [markdown]
# #### Function to connect to S3 bucket and download the csv file
# <span style="color:red">*Please don't modify the below cell*</span>

# %%
df = pd.read_csv('https://s3.amazonaws.com/phiga.tech/aps-dataset-citations-2020.csv')
# df.head()

# %%
def journal_correlation(dataframe, journalGrid):
    
    # START YOUR CODE HERE ---------
    
    newnodes = []
    for x in range(len(dataframe.index)):
#     for x in range(100000):
#         if(x%1000000==0):
#             print("STAUTS >>>> "+ str(round(x*1/len(df.index)*100,2))+"  ct: " + str(time.time()-start_time))
        
        new_node1 = dataframe['citing_doi'][x]
        s1 = new_node1
        sn = s1[s1.find('/')+1:]
        new_journal_id1 = sn[0:sn.find('.')]

        new_node2 = dataframe['cited_doi'][x]
        s2 = new_node2
        sn = s2[s2.find('/')+1:]
        new_journal_id2 = sn[0:sn.find('.')]
        
#         print(journalGrid[journalGrid['Journal']==new_journal_id1]['id'])

        if (
            (new_journal_id1 != new_journal_id2) and 
            (new_journal_id1 not in ['Physics','PhysRevFocus','PhysicsPhysiqueFizika']) and
            (new_journal_id2 not in ['Physics','PhysRevFocus','PhysicsPhysiqueFizika'])
            ):
#             new_journal_id1 = list(journalGrid[journalGrid['Journal']==new_journal_id1]['id'])[0]
#             new_journal_id2 = list(journalGrid[journalGrid['Journal']==new_journal_id2]['id'])[0]
            newnodes.append([str(new_journal_id1),str(new_journal_id2)])
    
    dataframe = pd.DataFrame(newnodes, columns=['from','to']).astype(np.uint8,errors='ignore')
    del newnodes
    cross_matrix = pd.crosstab(dataframe['from'],dataframe['to'])
    del dataframe
    
    name_change = {}
    for data in range(len(journalGrid[['id','Journal']])):
        name_change[str(journalGrid['Journal'][data])] = str(journalGrid['id'][data])
        
    cross_matrix = cross_matrix.rename(columns=name_change,index=name_change)
    results = cross_matrix
    
    # END YOUR CODE HERE -----------

    return results

# %%
journalGrid = journal_grid_color()
cross_data = journal_correlation(df, journalGrid)
display(cross_data)
# Out:
# to           PRXQUANTUM      PR     PRA  PRAB  PRAPPLIED     PRB    PRC  \
# from
# PRXQUANTUM            0      30     501     0         45     205      0
# PR                    0       0       6     0          0       6      0
# PRA                   5   69772       0    25        998   58108   3342
# PRAB                  0     175     274     0         17     130     20
# PRAPPLIED             3    1096    4149    43          0   15082     13
# PRB                   1  175694   59517     9       2298       0    873
# PRC                   0   49200    4146     2          3    1618      0
# PRD                   0   56563    9702    16         20    7645  29916
# PRE                   2   11047   60139    21        217   51726    894
# PRFLUIDS              0      81     284     0         80     218      1
# PRL                   5   64564  111482   151        965  274542  30478
# PRMATERIALS           0    1510     212     1        315   22818      2
# PRPER                 0       2       2     0          0       1      0
# PRRESEARCH            1    1155    7635    23        356   18646    295
# PRSTAB                0     346     539     0          2     201     83
# PRSTPER               0       5       0     0          0       0      0
# PRI                   0      13       0     0          0       0      0
# PRX                   1     888    5103    13        218   12818    108
# RMP                   0   28193   13410    18         72   25041   6053
#
# to             PRD    PRE  PRFLUIDS     PRL  PRMATERIALS  PRPER  PRRESEARCH  \
# from
# PRXQUANTUM      43     18         0     768            1      0          27
# PR               0      0         0   33278            0      0           0
# PRA          14331  15936         8  445961           11      0         410
# PRAB            94    448         0    2902            2      0           2
# PRAPPLIED      130   1090        25   16752          153      0          66
# PRB           8585  23903        35  987172         1819      0        1186
# PRC          42965    737         0  121068            1      0          20
# PRD              0   2124         5  314633            4      0         149
# PRE           3422      0       487  245297           64      0         166
# PRFLUIDS        24   4580         0    5879            4      0          13
# PRL          79968  46832       284       0          335      0         526
# PRMATERIALS     10    714         4   11732            0      0          35
# PRPER            2     10         0      11            0      0           0
# PRRESEARCH    2023   3688        66   23043          193      0           0
# PRSTAB         206   1382         0    3949            0      0           0
# PRSTPER          1      3         0       3            0      0           0
# PRI              0      0         0       0            0      0           0
# PRX           1142   2524        19   18818           68      7          86
# RMP          11884   4412         8   46275           10      0          17
#
# to           PRSTAB  PRSTPER  PRI    PRX    RMP
# from
# PRXQUANTUM        0        0    0    162    127
# PR                0        0    2      0  13786
# PRA             242        0    7   6020  44490
# PRAB           3844        0    5     58    250
# PRAPPLIED       108        0    3   1098   1713
# PRB              59        0   15  14846  86966
# PRC              45        0    0    101  13998
# PRD             110        0    0   1591  23432
# PRE             303        0    8   2454  21344
# PRFLUIDS          0        0    0     76    524
# PRL            1524        0   19   6774  40381
# PRMATERIALS       0        0    0    457   1225
# PRPER             0     2244    0      3      6
# PRRESEARCH       26        0    1   2385   3124
# PRSTAB            0        0    5      8    191
# PRSTPER           0        0    0      0      7
# PRI               0        0    0      0      0
# PRX              66        7    0      0   2129
# RMP             234        0    0    325      0

# %% [markdown]
# ### helper function. `matshow_cross()` function

# %%
def matshow_cross(cross_data):
    fig, ax = plt.subplots(1, 1, tight_layout=True)
    fig.set_size_inches(8, 7)
    # plt.rcParams["figure.figsize"] = (8,9)
    ax.axis('off')

    # plot
    
#     plt.matshow(cross_data.corr(), fignum=fig.number,cmap="Blues")
    plt.matshow(cross_data.corr(), fignum=fig.number)
    plt.xticks(range(cross_data.select_dtypes(['number']).shape[1]), cross_data.select_dtypes(['number']).columns, rotation=90)
    plt.yticks(range(cross_data.select_dtypes(['number']).shape[1]), cross_data.select_dtypes(['number']).columns)



    # font
    mpl.rcParams['font.family'] = 'serif'
    mpl.rcParams['mathtext.fontset'] = 'cm'
    plt.rcParams['font.size'] = 20
    plt.rcParams['axes.linewidth'] = 1


    cb = plt.colorbar()
    # cb.ax.tick_params(labelsize=14)

    # Add title
    plt.title('Correlation Matrix', pad=20)

    plt.savefig('./fig/corr_matrix.eps', format='eps',dpi=300, bbox_inches = "tight")
    # plt.tight_layout()
    return plt.show()

# %%
matshow_cross(cross_data)
# Out:
# C:\Users\costa\AppData\Local\Temp/ipykernel_10400/3840248979.py:29: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig('./fig/corr_matrix.eps', format='eps',dpi=300, bbox_inches = "tight")

# %% [markdown]
# # Implementation for the functions: <br> network extract

# %% [markdown]
# ### 1. `get_journal_for_doi()` function

# %% [markdown]
# ### 2. `get_authors_for_doi()` function

# %% [markdown]
# ### 3. `get_institutions_for_doi()` function

# %% [markdown]
# ### 4. `get_doi_list_for_author()` function

# %% [markdown]
# ### 5. `get_doi_list_for_institution()` function

# %%
def get_doi_list_for_institution(country, journal = ""):
    '''
    input: json file name
    output: full json obj
    '''
    # START YOUR CODE HERE ---------
    
    if journal == "":
        data = collection.find({"affiliations": { '$elemMatch': { 'name': { '$regex': country, "$options" : "i"} } }},{'_id'})
    else:
        data = collection.find({"affiliations": { '$elemMatch': { 'name': { '$regex': country, "$options" : "i"} } },"journal.id": journal},{'_id'})
    data = json.dumps(list(data))
    result = len(json.loads(data))

    # END YOUR CODE HERE -----------
    
    return result

# %%
get_doi_list_for_institution("Brazil")
# Out:
# 14247

# %%
get_doi_list_for_institution("Brazil")
# Out:
# 14247

# %%
get_doi_list_for_institution("Brazil","PRL")
# Out:
# 1182

# %%
country_json = pd.read_json('https://s3.amazonaws.com/phiga.tech/world_countries.json')
dataresult = []

for journals in list(journalGrid['id']):
    for data in country_json['features']:
        country_name = data['properties']['name']
        group_name = journals
        country_value = get_doi_list_for_institution(country_name,group_name)
        dataresult.append([group_name,country_name, country_value])

for data in country_json['features']: 
    country_name = data['properties']['name']
    group_name = "ALL"
    country_value = get_doi_list_for_institution(country_name)
    dataresult.append([group_name,country_name, country_value])

# %%
dataresult
# Out:
# [['PR', 'Afghanistan', 0],
#  ['PR', 'Angola', 0],
#  ['PR', 'Albania', 0],
#  ['PR', 'United Arab Emirates', 0],
#  ['PR', 'Argentina', 33],
#  ['PR', 'Armenia', 0],
#  ['PR', 'Antarctica', 0],
#  ['PR', 'French Southern and Antarctic Lands', 0],
#  ['PR', 'Australia', 223],
#  ['PR', 'Austria', 14],
#  ['PR', 'Azerbaijan', 0],
#  ['PR', 'Burundi', 0],
#  ['PR', 'Belgium', 53],
#  ['PR', 'Benin', 0],
#  ['PR', 'Burkina Faso', 0],
#  ['PR', 'Bangladesh', 0],
#  ['PR', 'Bulgaria', 0],
#  ['PR', 'The Bahamas', 0],
#  ['PR', 'Bosnia and Herzegovina', 0],
#  ['PR', 'Belarus', 0],
#  ['PR', 'Belize', 0],
#  ['PR', 'Bolivia', 2],
#  ['PR', 'Brazil', 70],
#  ['PR', 'Brunei', 0],
#  ['PR', 'Bhutan', 0],
#  ['PR', 'Botswana', 0],
#  ['PR', 'Central African Republic', 0],
#  ['PR', 'Canada', 950],
#  ['PR', 'Switzerland', 269],
#  ['PR', 'Chile', 7],
#  ['PR', 'China', 79],
#  ['PR', 'Ivory Coast', 0],
#  ['PR', 'Cameroon', 0],
#  ['PR', 'Democratic Republic of the Congo', 0],
#  ['PR', 'Republic of the Congo', 0],
#  ['PR', 'Colombia', 2],
#  ['PR', 'Costa Rica', 0],
#  ['PR', 'Cuba', 0],
#  ['PR', 'Northern Cyprus', 0],
#  ['PR', 'Cyprus', 0],
#  ['PR', 'Czech Republic', 0],
#  ['PR', 'Germany', 193],
#  ['PR', 'Djibouti', 0],
#  ['PR', 'Denmark', 205],
#  ['PR', 'Dominican Republic', 0],
#  ['PR', 'Algeria', 0],
#  ['PR', 'Ecuador', 0],
#  ['PR', 'Egypt', 6],
#  ['PR', 'Eritrea', 2],
#  ['PR', 'Spain', 3],
#  ['PR', 'Estonia', 1],
#  ['PR', 'Ethiopia', 0],
#  ['PR', 'Finland', 31],
#  ['PR', 'Fiji', 0],
#  ['PR', 'Falkland Islands', 0],
#  ['PR', 'France', 374],
#  ['PR', 'Gabon', 0],
#  ['PR', 'England', 1069],
#  ['PR', 'Georgia', 90],
#  ['PR', 'Ghana', 1],
#  ['PR', 'Guinea', 0],
#  ['PR', 'Gambia', 0],
#  ['PR', 'Guinea Bissau', 0],
#  ['PR', 'Equatorial Guinea', 0],
#  ['PR', 'Greece', 6],
#  ['PR', 'Greenland', 0],
#  ['PR', 'Guatemala', 0],
#  ['PR', 'Guyana', 0],
#  ['PR', 'Honduras', 0],
#  ['PR', 'Croatia', 0],
#  ['PR', 'Haiti', 0],
#  ['PR', 'Hungary', 38],
#  ['PR', 'Indonesia', 0],
#  ['PR', 'India', 1673],
#  ['PR', 'Ireland', 60],
#  ['PR', 'Iran', 0],
#  ['PR', 'Iraq', 0],
#  ['PR', 'Iceland', 0],
#  ['PR', 'Israel', 379],
#  ['PR', 'Italy', 433],
#  ['PR', 'Jamaica', 19],
#  ['PR', 'Jordan', 0],
#  ['PR', 'Japan', 450],
#  ['PR', 'Kazakhstan', 0],
#  ['PR', 'Kenya', 0],
#  ['PR', 'Kyrgyzstan', 0],
#  ['PR', 'Cambodia', 0],
#  ['PR', 'South Korea', 0],
#  ['PR', 'Kosovo', 0],
#  ['PR', 'Kuwait', 0],
#  ['PR', 'Laos', 0],
#  ['PR', 'Lebanon', 7],
#  ['PR', 'Liberia', 0],
#  ['PR', 'Libya', 0],
#  ['PR', 'Sri Lanka', 0],
#  ['PR', 'Lesotho', 0],
#  ['PR', 'Lithuania', 0],
#  ['PR', 'Luxembourg', 0],
#  ['PR', 'Latvia', 0],
#  ['PR', 'Morocco', 0],
#  ['PR', 'Moldova', 0],
#  ['PR', 'Madagascar', 0],
#  ['PR', 'Mexico', 915],
#  ['PR', 'Macedonia', 0],
#  ['PR', 'Mali', 49],
#  ['PR', 'Myanmar', 0],
#  ['PR', 'Montenegro', 0],
#  ['PR', 'Mongolia', 0],
#  ['PR', 'Mozambique', 0],
#  ['PR', 'Mauritania', 0],
#  ['PR', 'Malawi', 0],
#  ['PR', 'Malaysia', 1],
#  ['PR', 'Namibia', 0],
#  ['PR', 'New Caledonia', 0],
#  ['PR', 'Niger', 2],
#  ['PR', 'Nigeria', 2],
#  ['PR', 'Nicaragua', 0],
#  ['PR', 'Netherlands', 119],
#  ['PR', 'Norway', 80],
#  ['PR', 'Nepal', 0],
#  ['PR', 'New Zealand', 17],
#  ['PR', 'Oman', 7],
#  ['PR', 'Pakistan', 27],
#  ['PR', 'Panama', 1],
#  ['PR', 'Peru', 0],
#  ['PR', 'Philippines', 3],
#  ['PR', 'Papua New Guinea', 0],
#  ['PR', 'Poland', 71],
#  ['PR', 'Puerto Rico', 11],
#  ['PR', 'North Korea', 0],
#  ['PR', 'Portugal', 5],
#  ['PR', 'Paraguay', 0],
#  ['PR', 'Qatar', 0],
#  ['PR', 'Romania', 6],
#  ['PR', 'Russia', 3],
#  ['PR', 'Rwanda', 0],
#  ['PR', 'Western Sahara', 0],
#  ['PR', 'Saudi Arabia', 0],
#  ['PR', 'Sudan', 1],
#  ['PR', 'South Sudan', 0],
#  ['PR', 'Senegal', 0],
#  ['PR', 'Solomon Islands', 0],
#  ['PR', 'Sierra Leone', 0],
#  ['PR', 'El Salvador', 0],
#  ['PR', 'Somaliland', 0],
#  ['PR', 'Somalia', 0],
#  ['PR', 'Republic of Serbia', 0],
#  ['PR', 'Suriname', 0],
#  ['PR', 'Slovakia', 22],
#  ['PR', 'Slovenia', 0],
#  ['PR', 'Sweden', 253],
#  ['PR', 'Swaziland', 0],
#  ['PR', 'Syria', 0],
#  ['PR', 'Chad', 0],
#  ['PR', 'Togo', 0],
#  ['PR', 'Thailand', 0],
#  ['PR', 'Tajikistan', 0],
#  ['PR', 'Turkmenistan', 0],
#  ['PR', 'East Timor', 0],
#  ['PR', 'Trinidad and Tobago', 0],
#  ['PR', 'Tunisia', 0],
#  ['PR', 'Turkey', 12],
#  ['PR', 'Taiwan', 6],
#  ['PR', 'United Republic of Tanzania', 0],
#  ['PR', 'Uganda', 0],
#  ['PR', 'Ukraine', 0],
#  ['PR', 'Uruguay', 0],
#  ['PR', 'USA', 214],
#  ['PR', 'Uzbekistan', 0],
#  ['PR', 'Venezuela', 4],
#  ['PR', 'Vietnam', 0],
#  ['PR', 'Vanuatu', 0],
#  ['PR', 'West Bank', 0],
#  ['PR', 'Yemen', 0],
#  ['PR', 'South Africa', 50],
#  ['PR', 'Zambia', 0],
#  ['PR', 'Zimbabwe', 0],
#  ['PRA', 'Afghanistan', 0],
#  ['PRA', 'Angola', 0],
#  ['PRA', 'Albania', 0],
#  ['PRA', 'United Arab Emirates', 35],
#  ['PRA', 'Argentina', 879],
#  ['PRA', 'Armenia', 142],
#  ['PRA', 'Antarctica', 0],
#  ['PRA', 'French Southern and Antarctic Lands', 0],
#  ['PRA', 'Australia', 3004],
#  ['PRA', 'Austria', 1418],
#  ['PRA', 'Azerbaijan', 4],
#  ['PRA', 'Burundi', 1],
#  ['PRA', 'Belgium', 1029],
#  ['PRA', 'Benin', 1],
#  ['PRA', 'Burkina Faso', 0],
#  ['PRA', 'Bangladesh', 14],
#  ['PRA', 'Bulgaria', 206],
#  ['PRA', 'The Bahamas', 0],
#  ['PRA', 'Bosnia and Herzegovina', 63],
#  ['PRA', 'Belarus', 138],
#  ['PRA', 'Belize', 0],
#  ['PRA', 'Bolivia', 0],
#  ['PRA', 'Brazil', 2007],
#  ['PRA', 'Brunei', 0],
#  ['PRA', 'Bhutan', 0],
#  ['PRA', 'Botswana', 1],
#  ['PRA', 'Central African Republic', 0],
#  ['PRA', 'Canada', 3844],
#  ['PRA', 'Switzerland', 1134],
#  ['PRA', 'Chile', 267],
#  ['PRA', 'China', 8703],
#  ['PRA', 'Ivory Coast', 0],
#  ['PRA', 'Cameroon', 30],
#  ['PRA', 'Democratic Republic of the Congo', 0],
#  ['PRA', 'Republic of the Congo', 0],
#  ['PRA', 'Colombia', 109],
#  ['PRA', 'Costa Rica', 6],
#  ['PRA', 'Cuba', 13],
#  ['PRA', 'Northern Cyprus', 0],
#  ['PRA', 'Cyprus', 4],
#  ['PRA', 'Czech Republic', 667],
#  ['PRA', 'Germany', 10125],
#  ['PRA', 'Djibouti', 0],
#  ['PRA', 'Denmark', 1290],
#  ['PRA', 'Dominican Republic', 0],
#  ['PRA', 'Algeria', 100],
#  ['PRA', 'Ecuador', 13],
#  ['PRA', 'Egypt', 56],
#  ['PRA', 'Eritrea', 0],
#  ['PRA', 'Spain', 3008],
#  ['PRA', 'Estonia', 23],
#  ['PRA', 'Ethiopia', 17],
#  ['PRA', 'Finland', 804],
#  ['PRA', 'Fiji', 0],
#  ['PRA', 'Falkland Islands', 0],
#  ['PRA', 'France', 5494],
#  ['PRA', 'Gabon', 4],
#  ['PRA', 'England', 646],
#  ['PRA', 'Georgia', 921],
#  ['PRA', 'Ghana', 1],
#  ['PRA', 'Guinea', 0],
#  ['PRA', 'Gambia', 0],
#  ['PRA', 'Guinea Bissau', 0],
#  ['PRA', 'Equatorial Guinea', 0],
#  ['PRA', 'Greece', 541],
#  ['PRA', 'Greenland', 0],
#  ['PRA', 'Guatemala', 0],
#  ['PRA', 'Guyana', 0],
#  ['PRA', 'Honduras', 1],
#  ['PRA', 'Croatia', 128],
#  ['PRA', 'Haiti', 0],
#  ['PRA', 'Hungary', 694],
#  ['PRA', 'Indonesia', 15],
#  ['PRA', 'India', 3649],
#  ['PRA', 'Ireland', 345],
#  ['PRA', 'Iran', 368],
#  ['PRA', 'Iraq', 5],
#  ['PRA', 'Iceland', 18],
#  ['PRA', 'Israel', 2183],
#  ['PRA', 'Italy', 4024],
#  ['PRA', 'Jamaica', 15],
#  ['PRA', 'Jordan', 25],
#  ['PRA', 'Japan', 4559],
#  ['PRA', 'Kazakhstan', 27],
#  ['PRA', 'Kenya', 1],
#  ['PRA', 'Kyrgyzstan', 0],
#  ['PRA', 'Cambodia', 3],
#  ['PRA', 'South Korea', 55],
#  ['PRA', 'Kosovo', 0],
#  ['PRA', 'Kuwait', 11],
#  ['PRA', 'Laos', 0],
#  ['PRA', 'Lebanon', 13],
#  ['PRA', 'Liberia', 0],
#  ['PRA', 'Libya', 1],
#  ['PRA', 'Sri Lanka', 6],
#  ['PRA', 'Lesotho', 0],
#  ['PRA', 'Lithuania', 140],
#  ['PRA', 'Luxembourg', 7],
#  ['PRA', 'Latvia', 76],
#  ['PRA', 'Morocco', 30],
#  ['PRA', 'Moldova', 14],
#  ['PRA', 'Madagascar', 0],
#  ['PRA', 'Mexico', 2074],
#  ['PRA', 'Macedonia', 36],
#  ['PRA', 'Mali', 23],
#  ['PRA', 'Myanmar', 0],
#  ['PRA', 'Montenegro', 10],
#  ['PRA', 'Mongolia', 22],
#  ['PRA', 'Mozambique', 0],
#  ['PRA', 'Mauritania', 0],
#  ['PRA', 'Malawi', 0],
#  ['PRA', 'Malaysia', 84],
#  ['PRA', 'Namibia', 0],
#  ['PRA', 'New Caledonia', 1],
#  ['PRA', 'Niger', 5],
#  ['PRA', 'Nigeria', 4],
#  ['PRA', 'Nicaragua', 0],
#  ['PRA', 'Netherlands', 1415],
#  ['PRA', 'Norway', 333],
#  ['PRA', 'Nepal', 0],
#  ['PRA', 'New Zealand', 574],
#  ['PRA', 'Oman', 256],
#  ['PRA', 'Pakistan', 187],
#  ['PRA', 'Panama', 4],
#  ['PRA', 'Peru', 114],
#  ['PRA', 'Philippines', 21],
#  ['PRA', 'Papua New Guinea', 0],
#  ['PRA', 'Poland', 2074],
#  ['PRA', 'Puerto Rico', 40],
#  ['PRA', 'North Korea', 0],
#  ['PRA', 'Portugal', 307],
#  ['PRA', 'Paraguay', 0],
#  ['PRA', 'Qatar', 113],
#  ['PRA', 'Romania', 219],
#  ['PRA', 'Russia', 2982],
#  ['PRA', 'Rwanda', 0],
#  ['PRA', 'Western Sahara', 0],
#  ['PRA', 'Saudi Arabia', 173],
#  ['PRA', 'Sudan', 3],
#  ['PRA', 'South Sudan', 0],
#  ['PRA', 'Senegal', 1],
#  ['PRA', 'Solomon Islands', 0],
#  ['PRA', 'Sierra Leone', 0],
#  ['PRA', 'El Salvador', 0],
#  ['PRA', 'Somaliland', 0],
#  ['PRA', 'Somalia', 0],
#  ['PRA', 'Republic of Serbia', 0],
#  ['PRA', 'Suriname', 0],
#  ['PRA', 'Slovakia', 218],
#  ['PRA', 'Slovenia', 125],
#  ['PRA', 'Sweden', 1471],
#  ['PRA', 'Swaziland', 0],
#  ['PRA', 'Syria', 0],
#  ['PRA', 'Chad', 8],
#  ['PRA', 'Togo', 2],
#  ['PRA', 'Thailand', 20],
#  ['PRA', 'Tajikistan', 0],
#  ['PRA', 'Turkmenistan', 0],
#  ['PRA', 'East Timor', 0],
#  ['PRA', 'Trinidad and Tobago', 1],
#  ['PRA', 'Tunisia', 35],
#  ['PRA', 'Turkey', 303],
#  ['PRA', 'Taiwan', 765],
#  ['PRA', 'United Republic of Tanzania', 0],
#  ['PRA', 'Uganda', 0],
#  ['PRA', 'Ukraine', 222],
#  ['PRA', 'Uruguay', 56],
#  ['PRA', 'USA', 12292],
#  ['PRA', 'Uzbekistan', 92],
#  ['PRA', 'Venezuela', 59],
#  ['PRA', 'Vietnam', 70],
#  ['PRA', 'Vanuatu', 0],
#  ['PRA', 'West Bank', 8],
#  ['PRA', 'Yemen', 1],
#  ['PRA', 'South Africa', 199],
#  ['PRA', 'Zambia', 3],
#  ['PRA', 'Zimbabwe', 1],
#  ['PRAB', 'Afghanistan', 0],
#  ['PRAB', 'Angola', 0],
#  ['PRAB', 'Albania', 0],
#  ['PRAB', 'United Arab Emirates', 0],
#  ['PRAB', 'Argentina', 0],
#  ['PRAB', 'Armenia', 2],
#  ['PRAB', 'Antarctica', 0],
#  ['PRAB', 'French Southern and Antarctic Lands', 0],
#  ['PRAB', 'Australia', 6],
#  ['PRAB', 'Austria', 6],
#  ['PRAB', 'Azerbaijan', 0],
#  ['PRAB', 'Burundi', 0],
#  ['PRAB', 'Belgium', 3],
#  ['PRAB', 'Benin', 0],
#  ['PRAB', 'Burkina Faso', 0],
#  ['PRAB', 'Bangladesh', 0],
#  ['PRAB', 'Bulgaria', 0],
#  ['PRAB', 'The Bahamas', 0],
#  ['PRAB', 'Bosnia and Herzegovina', 0],
#  ['PRAB', 'Belarus', 8],
#  ['PRAB', 'Belize', 0],
#  ['PRAB', 'Bolivia', 0],
#  ['PRAB', 'Brazil', 1],
#  ['PRAB', 'Brunei', 0],
#  ['PRAB', 'Bhutan', 0],
#  ['PRAB', 'Botswana', 0],
#  ['PRAB', 'Central African Republic', 0],
#  ['PRAB', 'Canada', 13],
#  ['PRAB', 'Switzerland', 245],
#  ['PRAB', 'Chile', 0],
#  ['PRAB', 'China', 132],
#  ['PRAB', 'Ivory Coast', 0],
#  ['PRAB', 'Cameroon', 1],
#  ['PRAB', 'Democratic Republic of the Congo', 0],
#  ['PRAB', 'Republic of the Congo', 0],
#  ['PRAB', 'Colombia', 2],
#  ['PRAB', 'Costa Rica', 0],
#  ['PRAB', 'Cuba', 0],
#  ['PRAB', 'Northern Cyprus', 0],
#  ['PRAB', 'Cyprus', 0],
#  ['PRAB', 'Czech Republic', 5],
#  ['PRAB', 'Germany', 166],
#  ['PRAB', 'Djibouti', 0],
#  ['PRAB', 'Denmark', 3],
#  ['PRAB', 'Dominican Republic', 0],
#  ['PRAB', 'Algeria', 0],
#  ['PRAB', 'Ecuador', 0],
#  ['PRAB', 'Egypt', 0],
#  ['PRAB', 'Eritrea', 0],
#  ['PRAB', 'Spain', 28],
#  ['PRAB', 'Estonia', 0],
#  ['PRAB', 'Ethiopia', 0],
#  ['PRAB', 'Finland', 10],
#  ['PRAB', 'Fiji', 0],
#  ['PRAB', 'Falkland Islands', 0],
#  ['PRAB', 'France', 86],
#  ['PRAB', 'Gabon', 0],
#  ['PRAB', 'England', 2],
#  ['PRAB', 'Georgia', 0],
#  ['PRAB', 'Ghana', 0],
#  ['PRAB', 'Guinea', 0],
#  ['PRAB', 'Gambia', 0],
#  ['PRAB', 'Guinea Bissau', 0],
#  ['PRAB', 'Equatorial Guinea', 0],
#  ['PRAB', 'Greece', 10],
#  ['PRAB', 'Greenland', 0],
#  ['PRAB', 'Guatemala', 0],
#  ['PRAB', 'Guyana', 0],
#  ['PRAB', 'Honduras', 0],
#  ['PRAB', 'Croatia', 0],
#  ['PRAB', 'Haiti', 0],
#  ['PRAB', 'Hungary', 6],
#  ['PRAB', 'Indonesia', 2],
#  ['PRAB', 'India', 18],
#  ['PRAB', 'Ireland', 0],
#  ['PRAB', 'Iran', 7],
#  ['PRAB', 'Iraq', 0],
#  ['PRAB', 'Iceland', 0],
#  ['PRAB', 'Israel', 12],
#  ['PRAB', 'Italy', 103],
#  ['PRAB', 'Jamaica', 0],
#  ['PRAB', 'Jordan', 1],
#  ['PRAB', 'Japan', 104],
#  ['PRAB', 'Kazakhstan', 0],
#  ['PRAB', 'Kenya', 0],
#  ['PRAB', 'Kyrgyzstan', 0],
#  ['PRAB', 'Cambodia', 0],
#  ['PRAB', 'South Korea', 0],
#  ['PRAB', 'Kosovo', 0],
#  ['PRAB', 'Kuwait', 0],
#  ['PRAB', 'Laos', 0],
#  ['PRAB', 'Lebanon', 0],
#  ['PRAB', 'Liberia', 0],
#  ['PRAB', 'Libya', 0],
#  ['PRAB', 'Sri Lanka', 0],
#  ['PRAB', 'Lesotho', 0],
#  ['PRAB', 'Lithuania', 1],
#  ['PRAB', 'Luxembourg', 0],
#  ['PRAB', 'Latvia', 0],
#  ['PRAB', 'Morocco', 0],
#  ['PRAB', 'Moldova', 0],
#  ['PRAB', 'Madagascar', 0],
#  ['PRAB', 'Mexico', 31],
#  ['PRAB', 'Macedonia', 0],
#  ['PRAB', 'Mali', 0],
#  ['PRAB', 'Myanmar', 0],
#  ['PRAB', 'Montenegro', 0],
#  ['PRAB', 'Mongolia', 0],
#  ['PRAB', 'Mozambique', 0],
#  ['PRAB', 'Mauritania', 0],
#  ['PRAB', 'Malawi', 0],
#  ['PRAB', 'Malaysia', 1],
#  ['PRAB', 'Namibia', 0],
#  ['PRAB', 'New Caledonia', 0],
#  ['PRAB', 'Niger', 0],
#  ['PRAB', 'Nigeria', 0],
#  ['PRAB', 'Nicaragua', 0],
#  ['PRAB', 'Netherlands', 8],
#  ['PRAB', 'Norway', 11],
#  ['PRAB', 'Nepal', 0],
#  ['PRAB', 'New Zealand', 0],
#  ['PRAB', 'Oman', 0],
#  ['PRAB', 'Pakistan', 0],
#  ['PRAB', 'Panama', 0],
#  ['PRAB', 'Peru', 0],
#  ['PRAB', 'Philippines', 0],
#  ['PRAB', 'Papua New Guinea', 0],
#  ['PRAB', 'Poland', 8],
#  ['PRAB', 'Puerto Rico', 0],
#  ['PRAB', 'North Korea', 0],
#  ['PRAB', 'Portugal', 7],
#  ['PRAB', 'Paraguay', 0],
#  ['PRAB', 'Qatar', 0],
#  ['PRAB', 'Romania', 0],
#  ['PRAB', 'Russia', 71],
#  ['PRAB', 'Rwanda', 0],
#  ['PRAB', 'Western Sahara', 0],
#  ['PRAB', 'Saudi Arabia', 0],
#  ['PRAB', 'Sudan', 0],
#  ['PRAB', 'South Sudan', 0],
#  ['PRAB', 'Senegal', 0],
#  ['PRAB', 'Solomon Islands', 0],
#  ['PRAB', 'Sierra Leone', 0],
#  ['PRAB', 'El Salvador', 0],
#  ['PRAB', 'Somaliland', 0],
#  ['PRAB', 'Somalia', 0],
#  ['PRAB', 'Republic of Serbia', 0],
#  ['PRAB', 'Suriname', 0],
#  ['PRAB', 'Slovakia', 0],
#  ['PRAB', 'Slovenia', 4],
#  ['PRAB', 'Sweden', 36],
#  ['PRAB', 'Swaziland', 0],
#  ['PRAB', 'Syria', 0],
#  ['PRAB', 'Chad', 0],
#  ['PRAB', 'Togo', 0],
#  ['PRAB', 'Thailand', 0],
#  ['PRAB', 'Tajikistan', 0],
#  ['PRAB', 'Turkmenistan', 0],
#  ['PRAB', 'East Timor', 0],
#  ['PRAB', 'Trinidad and Tobago', 0],
#  ['PRAB', 'Tunisia', 0],
#  ['PRAB', 'Turkey', 0],
#  ['PRAB', 'Taiwan', 4],
#  ['PRAB', 'United Republic of Tanzania', 0],
#  ['PRAB', 'Uganda', 0],
#  ['PRAB', 'Ukraine', 10],
#  ['PRAB', 'Uruguay', 0],
#  ['PRAB', 'USA', 466],
#  ['PRAB', 'Uzbekistan', 0],
#  ['PRAB', 'Venezuela', 0],
#  ['PRAB', 'Vietnam', 0],
#  ['PRAB', 'Vanuatu', 0],
#  ['PRAB', 'West Bank', 0],
#  ['PRAB', 'Yemen', 0],
#  ['PRAB', 'South Africa', 0],
#  ['PRAB', 'Zambia', 0],
#  ['PRAB', 'Zimbabwe', 0],
#  ['PRAPPLIED', 'Afghanistan', 0],
#  ['PRAPPLIED', 'Angola', 0],
#  ['PRAPPLIED', 'Albania', 0],
#  ['PRAPPLIED', 'United Arab Emirates', 3],
#  ['PRAPPLIED', 'Argentina', 8],
#  ['PRAPPLIED', 'Armenia', 0],
#  ['PRAPPLIED', 'Antarctica', 0],
#  ['PRAPPLIED', 'French Southern and Antarctic Lands', 0],
#  ['PRAPPLIED', 'Australia', 143],
#  ['PRAPPLIED', 'Austria', 40],
#  ['PRAPPLIED', 'Azerbaijan', 0],
#  ['PRAPPLIED', 'Burundi', 0],
#  ['PRAPPLIED', 'Belgium', 38],
#  ['PRAPPLIED', 'Benin', 1],
#  ['PRAPPLIED', 'Burkina Faso', 0],
#  ['PRAPPLIED', 'Bangladesh', 1],
#  ['PRAPPLIED', 'Bulgaria', 2],
#  ['PRAPPLIED', 'The Bahamas', 0],
#  ['PRAPPLIED', 'Bosnia and Herzegovina', 0],
#  ['PRAPPLIED', 'Belarus', 5],
#  ['PRAPPLIED', 'Belize', 0],
#  ['PRAPPLIED', 'Bolivia', 0],
#  ['PRAPPLIED', 'Brazil', 34],
#  ['PRAPPLIED', 'Brunei', 0],
#  ['PRAPPLIED', 'Bhutan', 0],
#  ['PRAPPLIED', 'Botswana', 0],
#  ['PRAPPLIED', 'Central African Republic', 0],
#  ['PRAPPLIED', 'Canada', 116],
#  ['PRAPPLIED', 'Switzerland', 138],
#  ['PRAPPLIED', 'Chile', 10],
#  ['PRAPPLIED', 'China', 840],
#  ['PRAPPLIED', 'Ivory Coast', 0],
#  ['PRAPPLIED', 'Cameroon', 0],
#  ['PRAPPLIED', 'Democratic Republic of the Congo', 0],
#  ['PRAPPLIED', 'Republic of the Congo', 0],
#  ['PRAPPLIED', 'Colombia', 3],
#  ['PRAPPLIED', 'Costa Rica', 0],
#  ['PRAPPLIED', 'Cuba', 0],
#  ['PRAPPLIED', 'Northern Cyprus', 0],
#  ['PRAPPLIED', 'Cyprus', 1],
#  ['PRAPPLIED', 'Czech Republic', 33],
#  ['PRAPPLIED', 'Germany', 452],
#  ['PRAPPLIED', 'Djibouti', 0],
#  ['PRAPPLIED', 'Denmark', 54],
#  ['PRAPPLIED', 'Dominican Republic', 1],
#  ['PRAPPLIED', 'Algeria', 1],
#  ['PRAPPLIED', 'Ecuador', 0],
#  ['PRAPPLIED', 'Egypt', 4],
#  ['PRAPPLIED', 'Eritrea', 0],
#  ['PRAPPLIED', 'Spain', 143],
#  ['PRAPPLIED', 'Estonia', 0],
#  ['PRAPPLIED', 'Ethiopia', 0],
#  ['PRAPPLIED', 'Finland', 64],
#  ['PRAPPLIED', 'Fiji', 0],
#  ['PRAPPLIED', 'Falkland Islands', 0],
#  ['PRAPPLIED', 'France', 317],
#  ['PRAPPLIED', 'Gabon', 0],
#  ['PRAPPLIED', 'England', 2],
#  ['PRAPPLIED', 'Georgia', 26],
#  ['PRAPPLIED', 'Ghana', 0],
#  ['PRAPPLIED', 'Guinea', 0],
#  ['PRAPPLIED', 'Gambia', 0],
#  ['PRAPPLIED', 'Guinea Bissau', 0],
#  ['PRAPPLIED', 'Equatorial Guinea', 0],
#  ['PRAPPLIED', 'Greece', 11],
#  ['PRAPPLIED', 'Greenland', 0],
#  ['PRAPPLIED', 'Guatemala', 0],
#  ['PRAPPLIED', 'Guyana', 0],
#  ['PRAPPLIED', 'Honduras', 0],
#  ['PRAPPLIED', 'Croatia', 5],
#  ['PRAPPLIED', 'Haiti', 0],
#  ['PRAPPLIED', 'Hungary', 18],
#  ['PRAPPLIED', 'Indonesia', 0],
#  ['PRAPPLIED', 'India', 145],
#  ['PRAPPLIED', 'Ireland', 12],
#  ['PRAPPLIED', 'Iran', 25],
#  ['PRAPPLIED', 'Iraq', 0],
#  ['PRAPPLIED', 'Iceland', 4],
#  ['PRAPPLIED', 'Israel', 54],
#  ['PRAPPLIED', 'Italy', 161],
#  ['PRAPPLIED', 'Jamaica', 0],
#  ['PRAPPLIED', 'Jordan', 0],
#  ['PRAPPLIED', 'Japan', 323],
#  ['PRAPPLIED', 'Kazakhstan', 3],
#  ['PRAPPLIED', 'Kenya', 0],
#  ['PRAPPLIED', 'Kyrgyzstan', 0],
#  ['PRAPPLIED', 'Cambodia', 0],
#  ['PRAPPLIED', 'South Korea', 19],
#  ['PRAPPLIED', 'Kosovo', 0],
#  ['PRAPPLIED', 'Kuwait', 0],
#  ['PRAPPLIED', 'Laos', 0],
#  ['PRAPPLIED', 'Lebanon', 0],
#  ['PRAPPLIED', 'Liberia', 0],
#  ['PRAPPLIED', 'Libya', 0],
#  ['PRAPPLIED', 'Sri Lanka', 1],
#  ['PRAPPLIED', 'Lesotho', 0],
#  ['PRAPPLIED', 'Lithuania', 4],
#  ['PRAPPLIED', 'Luxembourg', 9],
#  ['PRAPPLIED', 'Latvia', 2],
#  ['PRAPPLIED', 'Morocco', 3],
#  ['PRAPPLIED', 'Moldova', 1],
#  ['PRAPPLIED', 'Madagascar', 0],
#  ['PRAPPLIED', 'Mexico', 59],
#  ['PRAPPLIED', 'Macedonia', 0],
#  ['PRAPPLIED', 'Mali', 7],
#  ['PRAPPLIED', 'Myanmar', 0],
#  ['PRAPPLIED', 'Montenegro', 1],
#  ['PRAPPLIED', 'Mongolia', 0],
#  ['PRAPPLIED', 'Mozambique', 0],
#  ['PRAPPLIED', 'Mauritania', 0],
#  ['PRAPPLIED', 'Malawi', 0],
#  ['PRAPPLIED', 'Malaysia', 1],
#  ['PRAPPLIED', 'Namibia', 0],
#  ['PRAPPLIED', 'New Caledonia', 0],
#  ['PRAPPLIED', 'Niger', 3],
#  ['PRAPPLIED', 'Nigeria', 3],
#  ['PRAPPLIED', 'Nicaragua', 0],
#  ['PRAPPLIED', 'Netherlands', 107],
#  ['PRAPPLIED', 'Norway', 13],
#  ['PRAPPLIED', 'Nepal', 0],
#  ['PRAPPLIED', 'New Zealand', 8],
#  ['PRAPPLIED', 'Oman', 17],
#  ['PRAPPLIED', 'Pakistan', 3],
#  ['PRAPPLIED', 'Panama', 0],
#  ['PRAPPLIED', 'Peru', 5],
#  ['PRAPPLIED', 'Philippines', 1],
#  ['PRAPPLIED', 'Papua New Guinea', 0],
#  ['PRAPPLIED', 'Poland', 54],
#  ['PRAPPLIED', 'Puerto Rico', 4],
#  ['PRAPPLIED', 'North Korea', 0],
#  ['PRAPPLIED', 'Portugal', 10],
#  ['PRAPPLIED', 'Paraguay', 0],
#  ['PRAPPLIED', 'Qatar', 1],
#  ['PRAPPLIED', 'Romania', 13],
#  ['PRAPPLIED', 'Russia', 162],
#  ['PRAPPLIED', 'Rwanda', 0],
#  ['PRAPPLIED', 'Western Sahara', 0],
#  ['PRAPPLIED', 'Saudi Arabia', 17],
#  ['PRAPPLIED', 'Sudan', 1],
#  ['PRAPPLIED', 'South Sudan', 0],
#  ['PRAPPLIED', 'Senegal', 0],
#  ['PRAPPLIED', 'Solomon Islands', 0],
#  ['PRAPPLIED', 'Sierra Leone', 0],
#  ['PRAPPLIED', 'El Salvador', 0],
#  ['PRAPPLIED', 'Somaliland', 0],
#  ['PRAPPLIED', 'Somalia', 0],
#  ['PRAPPLIED', 'Republic of Serbia', 0],
#  ['PRAPPLIED', 'Suriname', 0],
#  ['PRAPPLIED', 'Slovakia', 6],
#  ['PRAPPLIED', 'Slovenia', 0],
#  ['PRAPPLIED', 'Sweden', 65],
#  ['PRAPPLIED', 'Swaziland', 0],
#  ['PRAPPLIED', 'Syria', 0],
#  ['PRAPPLIED', 'Chad', 0],
#  ['PRAPPLIED', 'Togo', 0],
#  ['PRAPPLIED', 'Thailand', 2],
#  ['PRAPPLIED', 'Tajikistan', 1],
#  ['PRAPPLIED', 'Turkmenistan', 0],
#  ['PRAPPLIED', 'East Timor', 0],
#  ['PRAPPLIED', 'Trinidad and Tobago', 0],
#  ['PRAPPLIED', 'Tunisia', 1],
#  ['PRAPPLIED', 'Turkey', 19],
#  ['PRAPPLIED', 'Taiwan', 28],
#  ['PRAPPLIED', 'United Republic of Tanzania', 0],
#  ['PRAPPLIED', 'Uganda', 0],
#  ['PRAPPLIED', 'Ukraine', 39],
#  ['PRAPPLIED', 'Uruguay', 1],
#  ['PRAPPLIED', 'USA', 1275],
#  ['PRAPPLIED', 'Uzbekistan', 0],
#  ['PRAPPLIED', 'Venezuela', 0],
#  ['PRAPPLIED', 'Vietnam', 7],
#  ['PRAPPLIED', 'Vanuatu', 0],
#  ['PRAPPLIED', 'West Bank', 0],
#  ['PRAPPLIED', 'Yemen', 0],
#  ['PRAPPLIED', 'South Africa', 11],
#  ['PRAPPLIED', 'Zambia', 0],
#  ['PRAPPLIED', 'Zimbabwe', 0],
#  ['PRB', 'Afghanistan', 0],
#  ['PRB', 'Angola', 0],
#  ['PRB', 'Albania', 2],
#  ['PRB', 'United Arab Emirates', 20],
#  ['PRB', 'Argentina', 1817],
#  ['PRB', 'Armenia', 86],
#  ['PRB', 'Antarctica', 0],
#  ['PRB', 'French Southern and Antarctic Lands', 0],
#  ['PRB', 'Australia', 2348],
#  ['PRB', 'Austria', 2732],
#  ['PRB', 'Azerbaijan', 40],
#  ['PRB', 'Burundi', 3],
#  ['PRB', 'Belgium', 2701],
#  ['PRB', 'Benin', 4],
#  ['PRB', 'Burkina Faso', 2],
#  ['PRB', 'Bangladesh', 19],
#  ['PRB', 'Bulgaria', 285],
#  ['PRB', 'The Bahamas', 0],
#  ['PRB', 'Bosnia and Herzegovina', 1],
#  ['PRB', 'Belarus', 225],
#  ['PRB', 'Belize', 0],
#  ['PRB', 'Bolivia', 3],
#  ['PRB', 'Brazil', 4147],
#  ['PRB', 'Brunei', 0],
#  ['PRB', 'Bhutan', 0],
#  ['PRB', 'Botswana', 0],
#  ['PRB', 'Central African Republic', 0],
#  ['PRB', 'Canada', 8177],
#  ['PRB', 'Switzerland', 7118],
#  ['PRB', 'Chile', 458],
#  ['PRB', 'China', 13661],
#  ['PRB', 'Ivory Coast', 0],
#  ['PRB', 'Cameroon', 7],
#  ['PRB', 'Democratic Republic of the Congo', 0],
#  ['PRB', 'Republic of the Congo', 0],
#  ['PRB', 'Colombia', 184],
#  ['PRB', 'Costa Rica', 6],
#  ['PRB', 'Cuba', 126],
#  ['PRB', 'Northern Cyprus', 0],
#  ['PRB', 'Cyprus', 32],
#  ['PRB', 'Czech Republic', 1493],
#  ['PRB', 'Germany', 31808],
#  ['PRB', 'Djibouti', 1],
#  ['PRB', 'Denmark', 2488],
#  ['PRB', 'Dominican Republic', 1],
#  ['PRB', 'Algeria', 69],
#  ['PRB', 'Ecuador', 56],
#  ['PRB', 'Egypt', 88],
#  ['PRB', 'Eritrea', 0],
#  ['PRB', 'Spain', 7091],
#  ['PRB', 'Estonia', 179],
#  ['PRB', 'Ethiopia', 4],
#  ['PRB', 'Finland', 1944],
#  ['PRB', 'Fiji', 0],
#  ['PRB', 'Falkland Islands', 0],
#  ['PRB', 'France', 18570],
#  ['PRB', 'Gabon', 1],
#  ['PRB', 'England', 766],
#  ['PRB', 'Georgia', 1113],
#  ['PRB', 'Ghana', 1],
#  ['PRB', 'Guinea', 0],
#  ['PRB', 'Gambia', 0],
#  ['PRB', 'Guinea Bissau', 0],
#  ['PRB', 'Equatorial Guinea', 0],
#  ['PRB', 'Greece', 1052],
#  ['PRB', 'Greenland', 0],
#  ['PRB', 'Guatemala', 0],
#  ['PRB', 'Guyana', 1],
#  ['PRB', 'Honduras', 0],
#  ['PRB', 'Croatia', 385],
#  ['PRB', 'Haiti', 0],
#  ['PRB', 'Hungary', 1243],
#  ['PRB', 'Indonesia', 74],
#  ['PRB', 'India', 7533],
#  ['PRB', 'Ireland', 714],
#  ['PRB', 'Iran', 629],
#  ['PRB', 'Iraq', 7],
#  ['PRB', 'Iceland', 211],
#  ['PRB', 'Israel', 3962],
#  ['PRB', 'Italy', 9297],
#  ['PRB', 'Jamaica', 8],
#  ['PRB', 'Jordan', 36],
#  ['PRB', 'Japan', 20716],
#  ['PRB', 'Kazakhstan', 21],
#  ['PRB', 'Kenya', 5],
#  ['PRB', 'Kyrgyzstan', 2],
#  ['PRB', 'Cambodia', 0],
#  ['PRB', 'South Korea', 216],
#  ['PRB', 'Kosovo', 0],
#  ['PRB', 'Kuwait', 12],
#  ['PRB', 'Laos', 0],
#  ['PRB', 'Lebanon', 28],
#  ['PRB', 'Liberia', 0],
#  ['PRB', 'Libya', 3],
#  ['PRB', 'Sri Lanka', 23],
#  ['PRB', 'Lesotho', 1],
#  ['PRB', 'Lithuania', 143],
#  ['PRB', 'Luxembourg', 148],
#  ['PRB', 'Latvia', 88],
#  ['PRB', 'Morocco', 93],
#  ['PRB', 'Moldova', 177],
#  ['PRB', 'Madagascar', 0],
#  ['PRB', 'Mexico', 4862],
#  ['PRB', 'Macedonia', 4],
#  ['PRB', 'Mali', 96],
#  ['PRB', 'Myanmar', 0],
#  ['PRB', 'Montenegro', 35],
#  ['PRB', 'Mongolia', 23],
#  ['PRB', 'Mozambique', 0],
#  ['PRB', 'Mauritania', 0],
#  ['PRB', 'Malawi', 0],
#  ['PRB', 'Malaysia', 26],
#  ['PRB', 'Namibia', 0],
#  ['PRB', 'New Caledonia', 0],
#  ['PRB', 'Niger', 25],
#  ['PRB', 'Nigeria', 18],
#  ['PRB', 'Nicaragua', 0],
#  ['PRB', 'Netherlands', 5046],
#  ['PRB', 'Norway', 893],
#  ['PRB', 'Nepal', 9],
#  ['PRB', 'New Zealand', 421],
#  ['PRB', 'Oman', 800],
#  ['PRB', 'Pakistan', 64],
#  ['PRB', 'Panama', 2],
#  ['PRB', 'Peru', 176],
#  ['PRB', 'Philippines', 9],
#  ['PRB', 'Papua New Guinea', 0],
#  ['PRB', 'Poland', 3779],
#  ['PRB', 'Puerto Rico', 112],
#  ['PRB', 'North Korea', 0],
#  ['PRB', 'Portugal', 783],
#  ['PRB', 'Paraguay', 0],
#  ['PRB', 'Qatar', 18],
#  ['PRB', 'Romania', 413],
#  ['PRB', 'Russia', 8440],
#  ['PRB', 'Rwanda', 1],
#  ['PRB', 'Western Sahara', 0],
#  ['PRB', 'Saudi Arabia', 223],
#  ['PRB', 'Sudan', 6],
#  ['PRB', 'South Sudan', 0],
#  ['PRB', 'Senegal', 5],
#  ['PRB', 'Solomon Islands', 0],
#  ['PRB', 'Sierra Leone', 0],
#  ['PRB', 'El Salvador', 0],
#  ['PRB', 'Somaliland', 0],
#  ['PRB', 'Somalia', 0],
#  ['PRB', 'Republic of Serbia', 2],
#  ['PRB', 'Suriname', 0],
#  ['PRB', 'Slovakia', 436],
#  ['PRB', 'Slovenia', 642],
#  ['PRB', 'Sweden', 5122],
#  ['PRB', 'Swaziland', 0],
#  ['PRB', 'Syria', 3],
#  ['PRB', 'Chad', 0],
#  ['PRB', 'Togo', 5],
#  ['PRB', 'Thailand', 121],
#  ['PRB', 'Tajikistan', 7],
#  ['PRB', 'Turkmenistan', 0],
#  ['PRB', 'East Timor', 0],
#  ['PRB', 'Trinidad and Tobago', 0],
#  ['PRB', 'Tunisia', 66],
#  ['PRB', 'Turkey', 615],
#  ['PRB', 'Taiwan', 2360],
#  ['PRB', 'United Republic of Tanzania', 0],
#  ['PRB', 'Uganda', 0],
#  ['PRB', 'Ukraine', 2035],
#  ['PRB', 'Uruguay', 12],
#  ['PRB', 'USA', 34976],
#  ['PRB', 'Uzbekistan', 30],
#  ['PRB', 'Venezuela', 217],
#  ['PRB', 'Vietnam', 160],
#  ['PRB', 'Vanuatu', 0],
#  ['PRB', 'West Bank', 17],
#  ['PRB', 'Yemen', 1],
#  ['PRB', 'South Africa', 375],
#  ['PRB', 'Zambia', 1],
#  ['PRB', 'Zimbabwe', 2],
#  ['PRC', 'Afghanistan', 0],
#  ['PRC', 'Angola', 1],
#  ['PRC', 'Albania', 0],
#  ['PRC', 'United Arab Emirates', 10],
#  ['PRC', 'Argentina', 455],
#  ['PRC', 'Armenia', 68],
#  ['PRC', 'Antarctica', 0],
#  ['PRC', 'French Southern and Antarctic Lands', 0],
#  ['PRC', 'Australia', 807],
#  ['PRC', 'Austria', 230],
#  ['PRC', 'Azerbaijan', 9],
#  ['PRC', 'Burundi', 0],
#  ['PRC', 'Belgium', 1161],
#  ['PRC', 'Benin', 0],
#  ['PRC', 'Burkina Faso', 1],
#  ['PRC', 'Bangladesh', 24],
#  ['PRC', 'Bulgaria', 282],
#  ['PRC', 'The Bahamas', 0],
#  ['PRC', 'Bosnia and Herzegovina', 11],
#  ['PRC', 'Belarus', 24],
#  ['PRC', 'Belize', 0],
#  ['PRC', 'Bolivia', 0],
#  ['PRC', 'Brazil', 1036],
#  ['PRC', 'Brunei', 0],
#  ['PRC', 'Bhutan', 0],
#  ['PRC', 'Botswana', 6],
#  ['PRC', 'Central African Republic', 0],
#  ['PRC', 'Canada', 2000],
#  ['PRC', 'Switzerland', 639],
#  ['PRC', 'Chile', 77],
#  ['PRC', 'China', 3173],
#  ['PRC', 'Ivory Coast', 0],
#  ['PRC', 'Cameroon', 1],
#  ['PRC', 'Democratic Republic of the Congo', 0],
#  ['PRC', 'Republic of the Congo', 0],
#  ['PRC', 'Colombia', 43],
#  ['PRC', 'Costa Rica', 12],
#  ['PRC', 'Cuba', 28],
#  ['PRC', 'Northern Cyprus', 0],
#  ['PRC', 'Cyprus', 2],
#  ['PRC', 'Czech Republic', 295],
#  ['PRC', 'Germany', 5614],
#  ['PRC', 'Djibouti', 0],
#  ['PRC', 'Denmark', 430],
#  ['PRC', 'Dominican Republic', 0],
#  ['PRC', 'Algeria', 56],
#  ['PRC', 'Ecuador', 1],
#  ['PRC', 'Egypt', 140],
#  ['PRC', 'Eritrea', 0],
#  ['PRC', 'Spain', 1295],
#  ['PRC', 'Estonia', 0],
#  ['PRC', 'Ethiopia', 9],
#  ['PRC', 'Finland', 518],
#  ['PRC', 'Fiji', 0],
#  ['PRC', 'Falkland Islands', 0],
#  ['PRC', 'France', 3309],
#  ['PRC', 'Gabon', 0],
#  ['PRC', 'England', 138],
#  ['PRC', 'Georgia', 297],
#  ['PRC', 'Ghana', 1],
#  ['PRC', 'Guinea', 0],
#  ['PRC', 'Gambia', 0],
#  ['PRC', 'Guinea Bissau', 0],
#  ['PRC', 'Equatorial Guinea', 0],
#  ['PRC', 'Greece', 272],
#  ['PRC', 'Greenland', 0],
#  ['PRC', 'Guatemala', 1],
#  ['PRC', 'Guyana', 0],
#  ['PRC', 'Honduras', 1],
#  ['PRC', 'Croatia', 294],
#  ['PRC', 'Haiti', 0],
#  ['PRC', 'Hungary', 470],
#  ['PRC', 'Indonesia', 49],
#  ['PRC', 'India', 3986],
#  ['PRC', 'Ireland', 1],
#  ['PRC', 'Iran', 175],
#  ['PRC', 'Iraq', 20],
#  ['PRC', 'Iceland', 1],
#  ['PRC', 'Israel', 590],
#  ['PRC', 'Italy', 2376],
#  ['PRC', 'Jamaica', 2],
#  ['PRC', 'Jordan', 32],
#  ['PRC', 'Japan', 3495],
#  ['PRC', 'Kazakhstan', 26],
#  ['PRC', 'Kenya', 0],
#  ['PRC', 'Kyrgyzstan', 0],
#  ['PRC', 'Cambodia', 0],
#  ['PRC', 'South Korea', 16],
#  ['PRC', 'Kosovo', 0],
#  ['PRC', 'Kuwait', 39],
#  ['PRC', 'Laos', 0],
#  ['PRC', 'Lebanon', 10],
#  ['PRC', 'Liberia', 0],
#  ['PRC', 'Libya', 9],
#  ['PRC', 'Sri Lanka', 1],
#  ['PRC', 'Lesotho', 0],
#  ['PRC', 'Lithuania', 31],
#  ['PRC', 'Luxembourg', 0],
#  ['PRC', 'Latvia', 28],
#  ['PRC', 'Morocco', 11],
#  ['PRC', 'Moldova', 11],
#  ['PRC', 'Madagascar', 0],
#  ['PRC', 'Mexico', 2091],
#  ['PRC', 'Macedonia', 2],
#  ['PRC', 'Mali', 1],
#  ['PRC', 'Myanmar', 7],
#  ['PRC', 'Montenegro', 7],
#  ['PRC', 'Mongolia', 30],
#  ['PRC', 'Mozambique', 0],
#  ['PRC', 'Mauritania', 0],
#  ['PRC', 'Malawi', 0],
#  ['PRC', 'Malaysia', 24],
#  ['PRC', 'Namibia', 0],
#  ['PRC', 'New Caledonia', 0],
#  ['PRC', 'Niger', 14],
#  ...]

# %%
value_country = pd.DataFrame(dataresult, columns = ['Group','Country','Value'])
value_country['Key'] = 0

# %%
# value_country= value_country[value_country['Value'] != 0]

# %%
value_country
# Out:
#      Group               Country  Value  Key
# 0       PR           Afghanistan      0    0
# 1       PR                Angola      0    0
# 2       PR               Albania      0    0
# 3       PR  United Arab Emirates      0    0
# 4       PR             Argentina     33    0
# ...    ...                   ...    ...  ...
# 4066   ALL             West Bank     36    0
# 4067   ALL                 Yemen     11    0
# 4068   ALL          South Africa   2008    0
# 4069   ALL                Zambia      5    0
# 4070   ALL              Zimbabwe      3    0
#
# [4071 rows x 4 columns]

# %%
value_country.to_csv('./data/value-by-country.csv', header='true',index=False)

# %%
value_country.to_csv('../choropleth/value-by-country.csv', header='true',index=False)

# %% [markdown]
# # Implementation for the functions: <br> network analysis

# %% [markdown]
# ### 1. `add_node()` function

# %% [markdown]
# ### 2. `add_edge()` function

# %% [markdown]
# ### 3. `max_degree_nodes()` function

# %% [markdown]
# ### 4. `total_nodes()` function

# %% [markdown]
# ### 5. `total_edges()` function

# %% [markdown]
# ### 6. `write_edges_file()` function

# %% [markdown]
# ### 7. `write_nodes_file()` function

# %% [markdown]
# ### 8. `remove_single_leaf_nodes()` function
